# %%
import numpy
import matplotlib
import pandas as pd
from sklearn import cross_validation, tree, preprocessing, datasets

# %%
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip install torch
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more information on how to install packages:
#
#     https://docs.python.org/3/installing/

# %%
tds = pd.read_excel("titanic3.xls")

# %%
tds.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
tds['survived'].mean()
# Out:
# 0.3819709702062643

# %%
wom = tds.groupby(['sex','survived']).mean()
wom
# Out:
#                    pclass        age     sibsp     parch       fare       body
# sex    survived
# female 0         2.826772  25.255208  1.031496  0.889764  22.324084  166.62500
#        1         1.902655  29.815354  0.510324  0.536873  55.142048        NaN
# male   0         2.439883  31.516412  0.426686  0.224340  23.545868  160.39823
#        1         2.086957  26.977778  0.360248  0.347826  37.189053        NaN

# %%
tds.count()
# Out:
# pclass       1309
# survived     1309
# name         1309
# sex          1309
# age          1046
# sibsp        1309
# parch        1309
# ticket       1309
# fare         1308
# cabin         295
# embarked     1307
# boat          486
# body          121
# home.dest     745
# dtype: int64

# %%
tds.count()
# Out:
# pclass       1309
# survived     1309
# name         1309
# sex          1309
# age          1046
# sibsp        1309
# parch        1309
# ticket       1309
# fare         1308
# cabin         295
# embarked     1307
# boat          486
# body          121
# home.dest     745
# dtype: int64

# %%
tds = tds.drop(['cabin','boat','body'], axis = 1)

# %%
tds.count()
# Out:
# pclass       1309
# survived     1309
# name         1309
# sex          1309
# age          1046
# sibsp        1309
# parch        1309
# ticket       1309
# fare         1308
# embarked     1307
# home.dest     745
# dtype: int64

# %%
tds["home.dest"] = tds["home.dest"].fillna('NA')

# %%
tds.count()
# Out:
# pclass       1309
# survived     1309
# name         1309
# sex          1309
# age          1046
# sibsp        1309
# parch        1309
# ticket       1309
# fare         1308
# embarked     1307
# home.dest    1309
# dtype: int64

# %%
tds = tds.dropna()

# %%
tds.count()
# Out:
# pclass       1043
# survived     1043
# name         1043
# sex          1043
# age          1043
# sibsp        1043
# parch        1043
# ticket       1043
# fare         1043
# embarked     1043
# home.dest    1043
# dtype: int64

# %%
tds = tds.drop_duplicates()

# %%
tds.count()
# Out:
# pclass       1043
# survived     1043
# name         1043
# sex          1043
# age          1043
# sibsp        1043
# parch        1043
# ticket       1043
# fare         1043
# embarked     1043
# home.dest    1043
# dtype: int64

# %%
tds = tds.dropna()

# %%
tds.count()
# Out:
# pclass       1043
# survived     1043
# name         1043
# sex          1043
# age          1043
# sibsp        1043
# parch        1043
# ticket       1043
# fare         1043
# embarked     1043
# home.dest    1043
# dtype: int64

# %%
def preprocess_titanic(df):
    processed_df = df.copy()
    le = preprocessing.LabelEncoder()
    processed_df.sex = le.fit_transform(processed_df.sex)
    processed_df.embarked = le.fit_transform(processed_df.embarked)
    processed_df = processed_df.drop(['name', 'ticket', 'home.dest'], axis = 1)
    return processed_df

# %%
processed_df = preprocess_titanic(tds)

# %%
processed_df
# Out:
#       pclass  survived  sex      age  sibsp  parch      fare  embarked
# 0          1         1    0  29.0000      0      0  211.3375         2
# 1          1         1    1   0.9167      1      2  151.5500         2
# 2          1         0    0   2.0000      1      2  151.5500         2
# 3          1         0    1  30.0000      1      2  151.5500         2
# 4          1         0    0  25.0000      1      2  151.5500         2
# 5          1         1    1  48.0000      0      0   26.5500         2
# 6          1         1    0  63.0000      1      0   77.9583         2
# 7          1         0    1  39.0000      0      0    0.0000         2
# 8          1         1    0  53.0000      2      0   51.4792         2
# 9          1         0    1  71.0000      0      0   49.5042         0
# 10         1         0    1  47.0000      1      0  227.5250         0
# 11         1         1    0  18.0000      1      0  227.5250         0
# ...

# %%
X = processed_df.drop('survived',axis = 1).values
Y = processed_df['survived'].values

# %%
X_train, X_test, Y_train, Y_test = cross_validation.train_test_split(X,Y,test_size = 0.2)

# %%
clf_dt = tree.DecisionTreeClassifier(max_depth = 10)

# %%
clf_dt.fit(X_train, Y_train)
clf_dt.score(X_test, Y_test)
# Out:
# 0.7751196172248804

# %%
shuffle_validator = cross_validation.ShuffleSplit(len(X), n_iter=20, test_size=0.2, random_state=0)
def test_classifier(clf):
    scores = cross_validation.cross_val_score(clf, X, Y, cv=shuffle_validator)
    print("Accuracy: %0.4f (+/- %0.2f)" % (scores.mean(), scores.std()))

# %%
test_classifier(clf_dt)
# Out:
# Accuracy: 0.7744 (+/- 0.02)
